# %%
#QUESTÃO 7
#Urna Eletrônica
import time
print(60*'-')
print('Escolha do Usuário                 Candidato                      ')
print('        2201                         Paulo Manuel                 ')
print('        1705                         Maria Fernanda               ')
print('        1413                         Carlos Pedro                 ')
print('         00                          Nulo                         ')
print('         11                          Branco                       ')
print(60*'-')
ttv,pm,mf,cp,nl,br = 0,0,0,0,0,0
r = 'S'
while r == 'S':
    op = int(input('Entre com o número do Candito: '))
    if (op==2201):
        ttv+=1
        pm+=1
        #PAULO MANUEL
        print('\nVocê votou em Paulo Manuel.')
        r = str(input('Deseja continuar votando? [S/N]: ')).upper()
    elif (op==1705):
        ttv+=1
        mf+=1
        #MARIA FERNANDA
        print('\nVocê votou em Maria Fernanda.')
        r = str(input('Deseja continuar votando? {S/N}:')).upper()
    elif (op==1413):
        ttv+=1
        cp+=1
        #CARLOS PEDRO
        print('\nVocê votou em Carlos Pedro.')
        r = str(input('Deseja continuar votando? [S/N]: ')).upper()
    elif (op==0):
        ttv+=1
        nl+=1
        #VOTO NULO
        print('\n Você anulou seu voto.')
        r = str(input('Deseja continuar votando? [S/N]: ')).upper()
    elif (op==11):
        ttv+=1
        br+=1
        print('\nVocê votou branco.')
        r = str(input('Deseja continuar votando? [S/N]: ')).upper()
#1 - TOTAL DE VOTOS DE PAULO MANUEL
#2 - TOTAL DE VOTOS DE MARIA FERNANDA
#3 - TOTAL DE VOTOS DE CARLOS PEDRO
#4 - TOTAL DE VOTOS NULOS
#5 - TOTAL DE VOTOS EM BRANCO
#6 - TOTAL DE VOTOS (INCLUIR OS NULOS)
#7 - PERCENTUAL DE VOTOS NULOS
#8 - PERCENTUAL DE VOTOS BRANCOS
#9 - O VENCEDOR DA ELEIÇÃO
r2 = 'S'
while r2 == 'S':
    r2 = str(input('Deseja ver TODOS os votos, incluindo os nulos? [S/N]: ')).upper()
    if (r2=='S'):
        print(f'\nO total de votos em Paulo manuel foi de {pm}')
        print(f'\nO total de votos em Maria Fernanda foi de {mf}')
        print(f'\nO total de votos em Carlos Pedro foi de {cp}')
        print(f'\nO total de votos anulados foi de {nl}')
        print(f'\nO total de votos em branco foi de {br}')
        print(f'\nO total de votos, incluindo os nulos, foi de {ttv}')
        break
    else:
        print(f'\nO total de votos, incluindo os nulos, foi de {ttv}')
        if(pm>=1):
            print(f'\nO total de votos em Paulo Manuel foi de {pm}')
        if(mf>=1):
            print(f'\nO total de votos em Maria Fernanda foi de {mf}')
        if(cp>=1):
            print(f'\nO total de votos em Carlos Pedro foi de {cp}')
        if(nl>=1):
            print(f'\nO total de votos anulado foi de {nl}')
        if(br>=1):
            print(f'\nO total de votos em branco foi de {br}')
        
print(f'\nO percentual de votos anulados foi de {(nl/ttv)*100}%')
print(f'\nO percentual de votos em branco foi de {(br/ttv)*100}%')
time.sleep(1)
print('E o vencedor da eleição é..')
time.sleep(2)
if pm>mf and pm>cp:
    print('\nPaulo Manuel!! Parabéns.')
elif mf>pm and mf>cp:
    print('\nMaria Fernanda!! Parabéns.')
else:
    print('\nCarlos Pedro!! Parabéns. ')
time.sleep(2)
print('\nFim da Eleição.')
time.sleep(1)
print('\nObrigado por votar')
# Out:
# ------------------------------------------------------------
# Escolha do Usuário                 Candidato
#         2201                         Paulo Manuel
#         1705                         Maria Fernanda
#         1413                         Carlos Pedro
#          00                          Nulo
#          11                          Branco
# ------------------------------------------------------------
# Entre com o número do Candito: 2201
#
# Você votou em Paulo Manuel.
# Deseja continuar votando? [S/N]: s
# Entre com o número do Candito: 2201
#
# Você votou em Paulo Manuel.
# Deseja continuar votando? [S/N]: s
# Entre com o número do Candito: 00
#
#  Você anulou seu voto.
# Deseja continuar votando? [S/N]: n
# Deseja ver TODOS os votos, incluindo os nulos? [S/N]: s
#
# O total de votos em Paulo manuel foi de 2
#
# O total de votos em Maria Fernanda foi de 0
#
# O total de votos em Carlos Pedro foi de 0
#
# O total de votos anulados foi de 1
#
# ...
